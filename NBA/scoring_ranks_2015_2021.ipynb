# %%
from gazpacho import get, Soup
import pandas as pd

from datetime import timedelta, date

import time 
import tqdm

# %%
url = "https://www.teamrankings.com/nba/stat/points-per-game?date=2016-11-01"

# %%
html = get(url)

# %%
soup = Soup(html)

# %%
trs = soup.find('tr')

# %%
len(trs)
# Out:
# 31

# %%
tr_pop = trs.pop(0)

# %%
tr = trs[0]

# %%
rank = tr.find('td', {'class': 'rank text-center'}).text

# %%
team = tr.find('td', {'class': 'text-left nowrap'}).text

# %%
current_year_total = tr.find('td', {'class': 'text-right'})[0].text

# %%
last_three = tr.find('td', {'class': 'text-right'})[1].text

# %%
last_game  = tr.find('td', {'class': 'text-right'})[2].text

# %%
home_score_avg  = tr.find('td', {'class': 'text-right'})[3].text

# %%
away_score_avg  = tr.find('td', {'class': 'text-right'})[4].text

# %%
# Full 2015-16 season

# %%
def daterange(date1, date2):
    for n in range(int ((date2 - date1).days)+1):
        yield date1 + timedelta(n)

# %%
dates = 1
def scrape_page(dates=dates):
    url = 'https://www.teamrankings.com/nba/stat/points-per-game?date=' + str(dates) 
    html = get(url)
    soup = Soup(html)
    
    trs = soup.find('tr')
    tr_pop = trs.pop(0)
    tr = trs[0]
    
    def parse_tr(tr):
        return {
            'date': str(dates),
            'rank': tr.find('td', {'class': 'rank text-center'}).text,
            'team': tr.find('td', {'class': 'text-left nowrap'}).text,
            'current_year_total': tr.find('td', {'class': 'text-right'})[0].text,
            'last_three': tr.find('td', {'class': 'text-right'})[1].text,
            'last_game': tr.find('td', {'class': 'text-right'})[2].text,
            'home_score_avg': tr.find('td', {'class': 'text-right'})[3].text,
            'away_score_avg': tr.find('td', {'class': 'text-right'})[4].text,
        }
    
    
    rankers = [parse_tr(tr) for tr in trs]
    return rankers

# %%
data = []
start_dt = date(2015, 11, 3)             
end_dt = date(2016,4,13)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)

# %%
data
# Out:
# [{'away_score_avg': '123.0',
#   'current_year_total': '119.0',
#   'date': '2015-11-03',
#   'home_score_avg': '115.0',
#   'last_game': '119.0',
#   'last_three': '121.7',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '122.0',
#   'current_year_total': '118.2',
#   'date': '2015-11-03',
#   'home_score_avg': '114.5',
#   'last_game': '105.0',
#   'last_three': '120.3',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '109.0',
#   'current_year_total': '115.0',
#   'date': '2015-11-03',
#   'home_score_avg': '118.0',
#   'last_game': '109.0',
#   'last_three': '115.0',
#   'rank': '3',
#   'team': 'Sacramento'},
#  {'away_score_avg': '113.0',
#   'current_year_total': '108.3',
#   'date': '2015-11-03',
#   'home_score_avg': '106.0',
#   'last_game': '106.0',
#   'last_three': '108.3',
#   'rank': '4',
#   'team': 'Toronto'},
#  {'away_score_avg': '111.0',
#   'current_year_total': '107.8',
#   'date': '2015-11-03',
#   'home_score_avg': '106.7',
#   'last_game': '102.0',
#   'last_three': '106.7',
#   'rank': '5',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '119.5',
#   'current_year_total': '106.0',
#   'date': '2015-11-03',
#   'home_score_avg': '92.5',
#   'last_game': '84.0',
#   'last_three': '100.7',
#   'rank': '6',
#   'team': 'New York'},
#  {'away_score_avg': '114.0',
#   'current_year_total': '106.0',
#   'date': '2015-11-03',
#   'home_score_avg': '102.0',
#   'last_game': '93.0',
#   'last_three': '106.0',
#   'rank': '7',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '105.3',
#   'date': '2015-11-03',
#   'home_score_avg': '110.0',
#   'last_game': '110.0',
#   'last_three': '105.3',
#   'rank': '8',
#   'team': 'Washington'},
#  {'away_score_avg': '87.0',
#   'current_year_total': '103.3',
#   'date': '2015-11-03',
#   'home_score_avg': '111.5',
#   'last_game': '87.0',
#   'last_three': '103.3',
#   'rank': '9',
#   'team': 'Orlando'},
#  {'away_score_avg': '94.5',
#   'current_year_total': '103.0',
#   'date': '2015-11-03',
#   'home_score_avg': '120.0',
#   'last_game': '120.0',
#   'last_three': '103.0',
#   'rank': '10',
#   'team': 'New Orleans'},
#  {'away_score_avg': '103.5',
#   'current_year_total': '102.7',
#   'date': '2015-11-03',
#   'home_score_avg': '101.0',
#   'last_game': '101.0',
#   'last_three': '102.7',
#   'rank': '11',
#   'team': 'Minnesota'},
#  {'away_score_avg': '102.7',
#   'current_year_total': '102.5',
#   'date': '2015-11-03',
#   'home_score_avg': '102.0',
#   'last_game': '107.0',
#   'last_three': '105.0',
#   'rank': '12',
#   'team': 'Cleveland'},
#  {'away_score_avg': '92.0',
#   'current_year_total': '101.7',
#   'date': '2015-11-03',
#   'home_score_avg': '106.5',
#   'last_game': '109.0',
#   'last_three': '101.7',
#   'rank': '13',
#   'team': 'Miami'},
#  {'away_score_avg': '--',
#   'current_year_total': '100.7',
#   'date': '2015-11-03',
#   'home_score_avg': '100.7',
#   'last_game': '87.0',
#   'last_three': '100.7',
#   'rank': '14',
#   'team': 'Boston'},
#  {'away_score_avg': '100.7',
#   'current_year_total': '100.7',
#   'date': '2015-11-03',
#   'home_score_avg': '--',
#   'last_game': '103.0',
#   'last_three': '100.7',
#   'rank': '15',
#   'team': 'Dallas'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '100.5',
#   'date': '2015-11-03',
#   'home_score_avg': '102.5',
#   'last_game': '96.0',
#   'last_three': '102.3',
#   'rank': '16',
#   'team': 'Phoenix'},
#  {'away_score_avg': '95.0',
#   'current_year_total': '100.0',
#   'date': '2015-11-03',
#   'home_score_avg': '105.0',
#   'last_game': '103.0',
#   'last_three': '101.0',
#   'rank': '17',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '99.0',
#   'current_year_total': '100.0',
#   'date': '2015-11-03',
#   'home_score_avg': '101.0',
#   'last_game': '106.0',
#   'last_three': '96.0',
#   'rank': '18',
#   'team': 'Portland'},
#  {'away_score_avg': '104.5',
#   'current_year_total': '99.5',
#   'date': '2015-11-03',
#   'home_score_avg': '94.5',
#   'last_game': '92.0',
#   'last_three': '100.3',
#   'rank': '19',
#   'team': 'Chicago'},
#  {'away_score_avg': '98.3',
#   'current_year_total': '99.2',
#   'date': '2015-11-03',
#   'home_score_avg': '102.0',
#   'last_game': '94.0',
#   'last_three': '97.0',
#   'rank': '20',
#   'team': 'San Antonio'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '99.2',
#   'date': '2015-11-03',
#   'home_score_avg': '95.5',
#   'last_game': '94.0',
#   'last_three': '101.0',
#   'rank': '21',
#   'team': 'Atlanta'},
#  {'away_score_avg': '106.0',
#   'current_year_total': '98.7',
#   'date': '2015-11-03',
#   'home_score_avg': '95.0',
#   'last_game': '98.0',
#   'last_three': '98.7',
#   'rank': '22',
#   'team': 'Detroit'},
#  {'away_score_avg': '94.3',
#   'current_year_total': '94.3',
#   'date': '2015-11-03',
#   'home_score_avg': '--',
#   'last_game': '97.0',
#   'last_three': '94.3',
#   'rank': '23',
#   'team': 'Utah'},
#  {'away_score_avg': '89.0',
#   'current_year_total': '94.0',
#   'date': '2015-11-03',
#   'home_score_avg': '95.7',
#   'last_game': '110.0',
#   'last_three': '97.0',
#   'rank': '24',
#   'team': 'Houston'},
#  {'away_score_avg': '94.0',
#   'current_year_total': '93.3',
#   'date': '2015-11-03',
#   'home_score_avg': '92.0',
#   'last_game': '92.0',
#   'last_three': '93.3',
#   'rank': '25',
#   'team': 'Charlotte'},
#  {'away_score_avg': '99.0',
#   'current_year_total': '92.7',
#   'date': '2015-11-03',
#   'home_score_avg': '89.5',
#   'last_game': '76.0',
#   'last_three': '92.7',
#   'rank': '26',
#   'team': 'Indiana'},
#  {'away_score_avg': '99.0',
#   'current_year_total': '92.0',
#   'date': '2015-11-03',
#   'home_score_avg': '78.0',
#   'last_game': '93.0',
#   'last_three': '92.0',
#   'rank': '27',
#   'team': 'Denver'},
#  {'away_score_avg': '83.0',
#   'current_year_total': '90.5',
#   'date': '2015-11-03',
#   'home_score_avg': '98.0',
#   'last_game': '96.0',
#   'last_three': '87.3',
#   'rank': '28',
#   'team': 'Brooklyn'},
#  {'away_score_avg': '90.5',
#   'current_year_total': '89.5',
#   'date': '2015-11-03',
#   'home_score_avg': '88.5',
#   'last_game': '69.0',
#   'last_three': '94.0',
#   'rank': '29',
#   'team': 'Memphis'},
#  {'away_score_avg': '95.0',
#   'current_year_total': '88.7',
#   'date': '2015-11-03',
#   'home_score_avg': '85.5',
#   'last_game': '100.0',
#   'last_three': '88.7',
#   'rank': '30',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '123.0',
#   'current_year_total': '119.0',
#   'date': '2015-11-04',
#   'home_score_avg': '115.0',
#   'last_game': '119.0',
#   'last_three': '121.7',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '122.0',
#   'current_year_total': '118.2',
#   'date': '2015-11-04',
#   'home_score_avg': '114.5',
#   'last_game': '105.0',
#   'last_three': '120.3',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '109.0',
#   'current_year_total': '108.5',
#   'date': '2015-11-04',
#   'home_score_avg': '108.3',
#   'last_game': '89.0',
#   'last_three': '110.0',
#   'rank': '3',
#   'team': 'Sacramento'},
#  {'away_score_avg': '111.0',
#   'current_year_total': '107.8',
#   'date': '2015-11-04',
#   'home_score_avg': '106.7',
#   'last_game': '102.0',
#   'last_three': '106.7',
#   'rank': '4',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '114.0',
#   'current_year_total': '106.8',
#   'date': '2015-11-04',
#   'home_score_avg': '104.3',
#   'last_game': '109.0',
#   'last_three': '105.3',
#   'rank': '5',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '107.5',
#   'current_year_total': '106.8',
#   'date': '2015-11-04',
#   'home_score_avg': '106.0',
#   'last_game': '102.0',
#   'last_three': '107.0',
#   'rank': '6',
#   'team': 'Toronto'},
#  {'away_score_avg': '119.5',
#   'current_year_total': '106.0',
#   'date': '2015-11-04',
#   'home_score_avg': '92.5',
#   'last_game': '84.0',
#   'last_three': '100.7',
#   'rank': '7',
#   'team': 'New York'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '105.3',
#   'date': '2015-11-04',
#   'home_score_avg': '110.0',
#   'last_game': '110.0',
#   'last_three': '105.3',
#   'rank': '8',
#   'team': 'Washington'},
#  {'away_score_avg': '95.0',
#   'current_year_total': '103.2',
#   'date': '2015-11-04',
#   'home_score_avg': '111.5',
#   'last_game': '103.0',
#   'last_three': '108.7',
#   'rank': '9',
#   'team': 'Orlando'},
#  {'away_score_avg': '103.5',
#   'current_year_total': '102.7',
#   'date': '2015-11-04',
#   'home_score_avg': '101.0',
#   'last_game': '101.0',
#   'last_three': '102.7',
#   'rank': '10',
#   'team': 'Minnesota'},
#  {'away_score_avg': '94.0',
#   'current_year_total': '102.5',
#   'date': '2015-11-04',
#   'home_score_avg': '111.0',
#   'last_game': '130.0',
#   'last_three': '105.3',
#   'rank': '11',
#   'team': 'Charlotte'},
#  {'away_score_avg': '102.7',
#   'current_year_total': '102.5',
#   'date': '2015-11-04',
#   'home_score_avg': '102.0',
#   'last_game': '107.0',
#   'last_three': '105.0',
#   'rank': '12',
#   'team': 'Cleveland'},
#  {'away_score_avg': '94.5',
#   'current_year_total': '100.8',
#   'date': '2015-11-04',
#   'home_score_avg': '107.0',
#   'last_game': '94.0',
#   'last_three': '102.7',
#   'rank': '13',
#   'team': 'New Orleans'},
#  {'away_score_avg': '--',
#   'current_year_total': '100.7',
#   'date': '2015-11-04',
#   'home_score_avg': '100.7',
#   'last_game': '87.0',
#   'last_three': '100.7',
#   'rank': '14',
#   'team': 'Boston'},
#  {'away_score_avg': '104.7',
#   'current_year_total': '100.6',
#   'date': '2015-11-04',
#   'home_score_avg': '94.5',
#   'last_game': '105.0',
#   'last_three': '97.0',
#   'rank': '15',
#   'team': 'Chicago'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '100.5',
#   'date': '2015-11-04',
#   'home_score_avg': '102.5',
#   'last_game': '96.0',
#   'last_three': '102.3',
#   'rank': '16',
#   'team': 'Phoenix'},
#  {'away_score_avg': '99.0',
#   'current_year_total': '100.0',
#   'date': '2015-11-04',
#   'home_score_avg': '101.0',
#   'last_game': '106.0',
#   'last_three': '96.0',
#   'rank': '17',
#   'team': 'Portland'},
#  {'away_score_avg': '95.0',
#   'current_year_total': '100.0',
#   'date': '2015-11-04',
#   'home_score_avg': '105.0',
#   'last_game': '103.0',
#   'last_three': '101.0',
#   'rank': '18',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '92.0',
#   'current_year_total': '99.2',
#   'date': '2015-11-04',
#   'home_score_avg': '101.7',
#   'last_game': '92.0',
#   'last_three': '97.7',
#   'rank': '19',
#   'team': 'Miami'},
#  {'away_score_avg': '98.3',
#   'current_year_total': '99.2',
#   'date': '2015-11-04',
#   'home_score_avg': '102.0',
#   'last_game': '94.0',
#   'last_three': '97.0',
#   'rank': '20',
#   'team': 'San Antonio'},
#  {'away_score_avg': '106.0',
#   'current_year_total': '99.0',
#   'date': '2015-11-04',
#   'home_score_avg': '78.0',
#   'last_game': '120.0',
#   'last_three': '97.0',
#   'rank': '21',
#   'team': 'Denver'},
#  {'away_score_avg': '101.3',
#   'current_year_total': '99.0',
#   'date': '2015-11-04',
#   'home_score_avg': '95.5',
#   'last_game': '98.0',
#   'last_three': '96.3',
#   'rank': '22',
#   'team': 'Atlanta'},
#  {'away_score_avg': '100.7',
#   'current_year_total': '98.2',
#   'date': '2015-11-04',
#   'home_score_avg': '91.0',
#   'last_game': '91.0',
#   'last_three': '94.0',
#   'rank': '23',
#   'team': 'Dallas'},
#  {'away_score_avg': '106.0',
#   'current_year_total': '94.5',
#   'date': '2015-11-04',
#   'home_score_avg': '90.7',
#   'last_game': '82.0',
#   'last_three': '90.7',
#   'rank': '24',
#   'team': 'Detroit'},
#  {'away_score_avg': '94.3',
#   'current_year_total': '94.3',
#   'date': '2015-11-04',
#   'home_score_avg': '--',
#   'last_game': '97.0',
#   'last_three': '94.3',
#   'rank': '25',
#   'team': 'Utah'},
#  {'away_score_avg': '89.0',
#   'current_year_total': '94.0',
#   'date': '2015-11-04',
#   'home_score_avg': '95.7',
#   'last_game': '110.0',
#   'last_three': '97.0',
#   'rank': '26',
#   'team': 'Houston'},
#  {'away_score_avg': '96.5',
#   'current_year_total': '93.0',
#   'date': '2015-11-04',
#   'home_score_avg': '89.5',
#   'last_game': '94.0',
#   'last_three': '91.0',
#   'rank': '27',
#   'team': 'Indiana'},
#  {'away_score_avg': '94.7',
#   'current_year_total': '92.2',
#   'date': '2015-11-04',
#   'home_score_avg': '88.5',
#   'last_game': '103.0',
#   'last_three': '91.0',
#   'rank': '28',
#   'team': 'Memphis'},
#  {'away_score_avg': '83.0',
#   'current_year_total': '90.5',
#   'date': '2015-11-04',
#   'home_score_avg': '98.0',
#   'last_game': '96.0',
#   'last_three': '87.3',
#   'rank': '29',
#   'team': 'Brooklyn'},
#  {'away_score_avg': '95.0',
#   'current_year_total': '88.7',
#   'date': '2015-11-04',
#   'home_score_avg': '85.5',
#   'last_game': '100.0',
#   'last_three': '88.7',
#   'rank': '30',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '123.0',
#   'current_year_total': '117.6',
#   'date': '2015-11-05',
#   'home_score_avg': '114.0',
#   'last_game': '112.0',
#   'last_three': '121.7',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '122.0',
#   'current_year_total': '114.2',
#   'date': '2015-11-05',
#   'home_score_avg': '109.0',
#   'last_game': '98.0',
#   'last_three': '106.7',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '109.5',
#   'current_year_total': '107.8',
#   'date': '2015-11-05',
#   'home_score_avg': '106.7',
#   'last_game': '108.0',
#   'last_three': '108.0',
#   'rank': '3',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '114.0',
#   'current_year_total': '106.8',
#   'date': '2015-11-05',
#   'home_score_avg': '104.3',
#   'last_game': '109.0',
#   'last_three': '105.3',
#   'rank': '4',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '106.2',
#   'date': '2015-11-05',
#   'home_score_avg': '108.3',
#   'last_game': '97.0',
#   'last_three': '98.3',
#   'rank': '5',
#   'team': 'Sacramento'},
#  {'away_score_avg': '106.0',
#   'current_year_total': '106.0',
#   'date': '2015-11-05',
#   'home_score_avg': '106.0',
#   'last_game': '103.0',
#   'last_three': '103.7',
#   'rank': '6',
#   'team': 'Toronto'},
#  {'away_score_avg': '101.3',
#   'current_year_total': '105.4',
#   'date': '2015-11-05',
#   'home_score_avg': '111.5',
#   'last_game': '114.0',
#   'last_three': '101.3',
#   'rank': '7',
#   'team': 'Orlando'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '104.5',
#   'date': '2015-11-05',
#   'home_score_avg': '106.0',
#   'last_game': '102.0',
#   'last_three': '110.0',
#   'rank': '8',
#   'team': 'Washington'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '104.0',
#   'date': '2015-11-05',
#   'home_score_avg': '107.7',
#   'last_game': '118.0',
#   'last_three': '105.0',
#   'rank': '9',
#   'team': 'Phoenix'},
#  {'away_score_avg': '103.5',
#   'current_year_total': '102.7',
#   'date': '2015-11-05',
#   'home_score_avg': '101.0',
#   'last_game': '101.0',
#   'last_three': '102.7',
#   'rank': '10',
#   'team': 'Minnesota'},
#  {'away_score_avg': '94.0',
#   'current_year_total': '102.5',
#   'date': '2015-11-05',
#   'home_score_avg': '111.0',
#   'last_game': '130.0',
#   'last_three': '105.3',
#   'rank': '11',
#   'team': 'Charlotte'},
#  {'away_score_avg': '108.3',
#   'current_year_total': '102.0',
#   'date': '2015-11-05',
#   'home_score_avg': '92.5',
#   'last_game': '86.0',
#   'last_three': '95.7',
#   'rank': '12',
#   'team': 'New York'},
#  {'away_score_avg': '102.0',
#   'current_year_total': '101.6',
#   'date': '2015-11-05',
#   'home_score_avg': '101.0',
#   'last_game': '108.0',
#   'last_three': '101.3',
#   'rank': '13',
#   'team': 'Portland'},
#  {'away_score_avg': '102.7',
#   'current_year_total': '101.2',
#   'date': '2015-11-05',
#   'home_score_avg': '99.0',
#   'last_game': '96.0',
#   'last_three': '101.7',
#   'rank': '14',
#   'team': 'Cleveland'},
#  {'away_score_avg': '94.5',
#   'current_year_total': '100.8',
#   'date': '2015-11-05',
#   'home_score_avg': '107.0',
#   'last_game': '94.0',
#   'last_three': '102.7',
#   'rank': '15',
#   'team': 'New Orleans'},
#  {'away_score_avg': '104.7',
#   'current_year_total': '100.6',
#   'date': '2015-11-05',
#   'home_score_avg': '94.5',
#   'last_game': '105.0',
#   'last_three': '97.0',
#   'rank': '16',
#   'team': 'Chicago'},
#  {'away_score_avg': '98.0',
#   'current_year_total': '100.0',
#   'date': '2015-11-05',
#   'home_score_avg': '100.7',
#   'last_game': '98.0',
#   'last_three': '96.0',
#   'rank': '17',
#   'team': 'Boston'},
#  {'away_score_avg': '101.3',
#   'current_year_total': '99.3',
#   'date': '2015-11-05',
#   'home_score_avg': '97.3',
#   'last_game': '101.0',
#   'last_three': '97.7',
#   'rank': '18',
#   'team': 'Atlanta'},
#  {'away_score_avg': '92.0',
#   'current_year_total': '99.2',
#   'date': '2015-11-05',
#   'home_score_avg': '101.7',
#   'last_game': '92.0',
#   'last_three': '97.7',
#   'rank': '19',
#   'team': 'Miami'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '99.2',
#   'date': '2015-11-05',
#   'home_score_avg': '102.0',
#   'last_game': '99.0',
#   'last_three': '96.0',
#   'rank': '20',
#   'team': 'San Antonio'},
#  {'away_score_avg': '89.0',
#   'current_year_total': '99.0',
#   'date': '2015-11-05',
#   'home_score_avg': '101.5',
#   'last_game': '119.0',
#   'last_three': '106.0',
#   'rank': '21',
#   'team': 'Houston'},
#  {'away_score_avg': '106.0',
#   'current_year_total': '99.0',
#   'date': '2015-11-05',
#   'home_score_avg': '78.0',
#   'last_game': '120.0',
#   'last_three': '97.0',
#   'rank': '22',
#   'team': 'Denver'},
#  {'away_score_avg': '100.7',
#   'current_year_total': '98.2',
#   'date': '2015-11-05',
#   'home_score_avg': '91.0',
#   'last_game': '91.0',
#   'last_three': '94.0',
#   'rank': '23',
#   'team': 'Dallas'},
#  {'away_score_avg': '95.0',
#   'current_year_total': '98.2',
#   'date': '2015-11-05',
#   'home_score_avg': '100.3',
#   'last_game': '91.0',
#   'last_three': '93.7',
#   'rank': '24',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '106.0',
#   'current_year_total': '94.5',
#   'date': '2015-11-05',
#   'home_score_avg': '90.7',
#   'last_game': '82.0',
#   'last_three': '90.7',
#   'rank': '25',
#   'team': 'Detroit'},
#  {'away_score_avg': '96.5',
#   'current_year_total': '94.4',
#   'date': '2015-11-05',
#   'home_score_avg': '93.0',
#   'last_game': '100.0',
#   'last_three': '90.0',
#   'rank': '26',
#   'team': 'Indiana'},
#  {'away_score_avg': '94.3',
#   'current_year_total': '93.8',
#   'date': '2015-11-05',
#   'home_score_avg': '92.0',
#   'last_game': '92.0',
#   'last_three': '96.0',
#   'rank': '27',
#   'team': 'Utah'},
#  {'away_score_avg': '94.7',
#   'current_year_total': '92.2',
#   'date': '2015-11-05',
#   'home_score_avg': '88.5',
#   'last_game': '103.0',
#   'last_three': '91.0',
#   'rank': '28',
#   'team': 'Memphis'},
#  {'away_score_avg': '84.3',
#   'current_year_total': '89.8',
#   'date': '2015-11-05',
#   'home_score_avg': '98.0',
#   'last_game': '87.0',
#   'last_three': '91.3',
#   'rank': '29',
#   'team': 'Brooklyn'},
#  {'away_score_avg': '91.0',
#   'current_year_total': '88.2',
#   'date': '2015-11-05',
#   'home_score_avg': '85.5',
#   'last_game': '87.0',
#   'last_three': '86.0',
#   'rank': '30',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '123.0',
#   'current_year_total': '117.6',
#   'date': '2015-11-06',
#   'home_score_avg': '114.0',
#   'last_game': '112.0',
#   'last_three': '121.7',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '114.0',
#   'current_year_total': '111.5',
#   'date': '2015-11-06',
#   'home_score_avg': '109.0',
#   'last_game': '98.0',
#   'last_three': '100.3',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '109.5',
#   'current_year_total': '107.8',
#   'date': '2015-11-06',
#   'home_score_avg': '106.7',
#   'last_game': '108.0',
#   'last_three': '108.0',
#   'rank': '3',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '114.0',
#   'current_year_total': '106.8',
#   'date': '2015-11-06',
#   'home_score_avg': '104.3',
#   'last_game': '109.0',
#   'last_three': '105.3',
#   'rank': '4',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '106.2',
#   'date': '2015-11-06',
#   'home_score_avg': '108.3',
#   'last_game': '97.0',
#   'last_three': '98.3',
#   'rank': '5',
#   'team': 'Sacramento'},
#  {'away_score_avg': '106.0',
#   'current_year_total': '106.0',
#   'date': '2015-11-06',
#   'home_score_avg': '106.0',
#   'last_game': '103.0',
#   'last_three': '103.7',
#   'rank': '6',
#   'team': 'Toronto'},
#  {'away_score_avg': '101.3',
#   'current_year_total': '105.4',
#   'date': '2015-11-06',
#   'home_score_avg': '111.5',
#   'last_game': '114.0',
#   'last_three': '101.3',
#   'rank': '7',
#   'team': 'Orlando'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '104.5',
#   'date': '2015-11-06',
#   'home_score_avg': '106.0',
#   'last_game': '102.0',
#   'last_three': '110.0',
#   'rank': '8',
#   'team': 'Washington'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '104.0',
#   'date': '2015-11-06',
#   'home_score_avg': '107.7',
#   'last_game': '118.0',
#   'last_three': '105.0',
#   'rank': '9',
#   'team': 'Phoenix'},
#  {'away_score_avg': '102.0',
#   'current_year_total': '103.8',
#   'date': '2015-11-06',
#   'home_score_avg': '105.7',
#   'last_game': '115.0',
#   'last_three': '109.7',
#   'rank': '10',
#   'team': 'Portland'},
#  {'away_score_avg': '98.7',
#   'current_year_total': '103.6',
#   'date': '2015-11-06',
#   'home_score_avg': '111.0',
#   'last_game': '108.0',
#   'last_three': '110.0',
#   'rank': '11',
#   'team': 'Charlotte'},
#  {'away_score_avg': '108.3',
#   'current_year_total': '102.0',
#   'date': '2015-11-06',
#   'home_score_avg': '92.5',
#   'last_game': '86.0',
#   'last_three': '95.7',
#   'rank': '12',
#   'team': 'New York'},
#  {'away_score_avg': '102.7',
#   'current_year_total': '101.2',
#   'date': '2015-11-06',
#   'home_score_avg': '99.0',
#   'last_game': '96.0',
#   'last_three': '101.7',
#   'rank': '13',
#   'team': 'Cleveland'},
#  {'away_score_avg': '104.7',
#   'current_year_total': '101.2',
#   'date': '2015-11-06',
#   'home_score_avg': '97.7',
#   'last_game': '104.0',
#   'last_three': '100.3',
#   'rank': '14',
#   'team': 'Chicago'},
#  {'away_score_avg': '94.5',
#   'current_year_total': '100.8',
#   'date': '2015-11-06',
#   'home_score_avg': '107.0',
#   'last_game': '94.0',
#   'last_three': '102.7',
#   'rank': '15',
#   'team': 'New Orleans'},
#  {'away_score_avg': '98.0',
#   'current_year_total': '100.0',
#   'date': '2015-11-06',
#   'home_score_avg': '100.7',
#   'last_game': '98.0',
#   'last_three': '96.0',
#   'rank': '16',
#   'team': 'Boston'},
#  {'away_score_avg': '101.3',
#   'current_year_total': '99.3',
#   'date': '2015-11-06',
#   'home_score_avg': '97.3',
#   'last_game': '101.0',
#   'last_three': '97.7',
#   'rank': '17',
#   'team': 'Atlanta'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '99.2',
#   'date': '2015-11-06',
#   'home_score_avg': '102.0',
#   'last_game': '99.0',
#   'last_three': '96.0',
#   'rank': '18',
#   'team': 'San Antonio'},
#  {'away_score_avg': '89.0',
#   'current_year_total': '99.0',
#   'date': '2015-11-06',
#   'home_score_avg': '101.5',
#   'last_game': '119.0',
#   'last_three': '106.0',
#   'rank': '19',
#   'team': 'Houston'},
#  {'away_score_avg': '94.0',
#   'current_year_total': '98.6',
#   'date': '2015-11-06',
#   'home_score_avg': '101.7',
#   'last_game': '96.0',
#   'last_three': '99.0',
#   'rank': '20',
#   'team': 'Miami'},
#  {'away_score_avg': '95.0',
#   'current_year_total': '98.2',
#   'date': '2015-11-06',
#   'home_score_avg': '100.3',
#   'last_game': '91.0',
#   'last_three': '93.7',
#   'rank': '21',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '103.5',
#   'current_year_total': '98.0',
#   'date': '2015-11-06',
#   'home_score_avg': '92.5',
#   'last_game': '84.0',
#   'last_three': '93.3',
#   'rank': '22',
#   'team': 'Minnesota'},
#  {'away_score_avg': '100.7',
#   'current_year_total': '97.4',
#   'date': '2015-11-06',
#   'home_score_avg': '92.5',
#   'last_game': '94.0',
#   'last_three': '96.0',
#   'rank': '23',
#   'team': 'Dallas'},
#  {'away_score_avg': '106.0',
#   'current_year_total': '96.0',
#   'date': '2015-11-06',
#   'home_score_avg': '81.0',
#   'last_game': '84.0',
#   'last_three': '99.0',
#   'rank': '24',
#   'team': 'Denver'},
#  {'away_score_avg': '106.0',
#   'current_year_total': '94.5',
#   'date': '2015-11-06',
#   'home_score_avg': '90.7',
#   'last_game': '82.0',
#   'last_three': '90.7',
#   'rank': '25',
#   'team': 'Detroit'},
#  {'away_score_avg': '96.5',
#   'current_year_total': '94.4',
#   'date': '2015-11-06',
#   'home_score_avg': '93.0',
#   'last_game': '100.0',
#   'last_three': '90.0',
#   'rank': '26',
#   'team': 'Indiana'},
#  {'away_score_avg': '94.8',
#   'current_year_total': '94.2',
#   'date': '2015-11-06',
#   'home_score_avg': '92.0',
#   'last_game': '96.0',
#   'last_three': '95.0',
#   'rank': '27',
#   'team': 'Utah'},
#  {'away_score_avg': '95.0',
#   'current_year_total': '92.8',
#   'date': '2015-11-06',
#   'home_score_avg': '88.5',
#   'last_game': '96.0',
#   'last_three': '89.3',
#   'rank': '28',
#   'team': 'Memphis'},
#  {'away_score_avg': '84.3',
#   'current_year_total': '89.8',
#   'date': '2015-11-06',
#   'home_score_avg': '98.0',
#   'last_game': '87.0',
#   'last_three': '91.3',
#   'rank': '29',
#   'team': 'Brooklyn'},
#  {'away_score_avg': '91.0',
#   'current_year_total': '88.2',
#   'date': '2015-11-06',
#   'home_score_avg': '85.5',
#   'last_game': '87.0',
#   'last_three': '86.0',
#   'rank': '30',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '123.0',
#   'current_year_total': '117.8',
#   'date': '2015-11-07',
#   'home_score_avg': '115.2',
#   'last_game': '119.0',
#   'last_three': '116.7',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '114.0',
#   'current_year_total': '111.5',
#   'date': '2015-11-07',
#   'home_score_avg': '109.0',
#   'last_game': '98.0',
#   'last_three': '100.3',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '109.5',
#   'current_year_total': '107.8',
#   'date': '2015-11-07',
#   'home_score_avg': '106.7',
#   'last_game': '108.0',
#   'last_three': '108.0',
#   'rank': '3',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '106.8',
#   'date': '2015-11-07',
#   'home_score_avg': '108.8',
#   'last_game': '110.0',
#   'last_three': '98.7',
#   'rank': '4',
#   'team': 'Sacramento'},
#  {'away_score_avg': '109.0',
#   'current_year_total': '106.2',
#   'date': '2015-11-07',
#   'home_score_avg': '104.3',
#   'last_game': '104.0',
#   'last_three': '102.0',
#   'rank': '5',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '102.0',
#   'current_year_total': '103.8',
#   'date': '2015-11-07',
#   'home_score_avg': '105.7',
#   'last_game': '115.0',
#   'last_three': '109.7',
#   'rank': '6',
#   'team': 'Portland'},
#  {'away_score_avg': '98.7',
#   'current_year_total': '103.6',
#   'date': '2015-11-07',
#   'home_score_avg': '111.0',
#   'last_game': '108.0',
#   'last_three': '110.0',
#   'rank': '7',
#   'team': 'Charlotte'},
#  {'away_score_avg': '94.5',
#   'current_year_total': '103.6',
#   'date': '2015-11-07',
#   'home_score_avg': '109.7',
#   'last_game': '115.0',
#   'last_three': '109.7',
#   'rank': '8',
#   'team': 'New Orleans'},
#  {'away_score_avg': '98.0',
#   'current_year_total': '103.6',
#   'date': '2015-11-07',
#   'home_score_avg': '105.0',
#   'last_game': '118.0',
#   'last_three': '101.0',
#   'rank': '9',
#   'team': 'Boston'},
#  {'away_score_avg': '101.3',
#   'current_year_total': '103.2',
#   'date': '2015-11-07',
#   'home_score_avg': '106.0',
#   'last_game': '98.0',
#   'last_three': '103.3',
#   'rank': '10',
#   'team': 'Washington'},
#  {'away_score_avg': '101.3',
#   'current_year_total': '103.2',
#   'date': '2015-11-07',
#   'home_score_avg': '105.0',
#   'last_game': '92.0',
#   'last_three': '103.0',
#   'rank': '11',
#   'team': 'Orlando'},
#  {'away_score_avg': '101.2',
#   'current_year_total': '102.8',
#   'date': '2015-11-07',
#   'home_score_avg': '106.0',
#   'last_game': '87.0',
#   'last_three': '97.3',
#   'rank': '12',
#   'team': 'Toronto'},
#  {'away_score_avg': '106.2',
#   'current_year_total': '102.4',
#   'date': '2015-11-07',
#   'home_score_avg': '97.3',
#   'last_game': '121.0',
#   'last_three': '106.7',
#   'rank': '13',
#   'team': 'Atlanta'},
#  {'away_score_avg': '102.7',
#   'current_year_total': '102.3',
#   'date': '2015-11-07',
#   'home_score_avg': '102.0',
#   'last_game': '108.0',
#   'last_three': '103.7',
#   'rank': '14',
#   'team': 'Cleveland'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '102.0',
#   'date': '2015-11-07',
#   'home_score_avg': '103.8',
#   'last_game': '92.0',
#   'last_three': '102.0',
#   'rank': '15',
#   'team': 'Phoenix'},
#  {'away_score_avg': '102.5',
#   'current_year_total': '101.8',
#   'date': '2015-11-07',
#   'home_score_avg': '101.5',
#   'last_game': '116.0',
#   'last_three': '115.0',
#   'rank': '16',
#   'team': 'Houston'},
#  {'away_score_avg': '104.7',
#   'current_year_total': '101.2',
#   'date': '2015-11-07',
#   'home_score_avg': '97.7',
#   'last_game': '104.0',
#   'last_three': '100.3',
#   'rank': '17',
#   'team': 'Chicago'},
#  {'away_score_avg': '108.3',
#   'current_year_total': '100.3',
#   'date': '2015-11-07',
#   'home_score_avg': '92.3',
#   'last_game': '92.0',
#   'last_three': '87.3',
#   'rank': '18',
#   'team': 'New York'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '99.2',
#   'date': '2015-11-07',
#   'home_score_avg': '102.0',
#   'last_game': '99.0',
#   'last_three': '96.0',
#   'rank': '19',
#   'team': 'San Antonio'},
#  {'away_score_avg': '96.3',
#   'current_year_total': '98.3',
#   'date': '2015-11-07',
#   'home_score_avg': '100.3',
#   'last_game': '99.0',
#   'last_three': '97.7',
#   'rank': '20',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '103.5',
#   'current_year_total': '98.0',
#   'date': '2015-11-07',
#   'home_score_avg': '92.5',
#   'last_game': '84.0',
#   'last_three': '93.3',
#   'rank': '21',
#   'team': 'Minnesota'},
#  {'away_score_avg': '100.7',
#   'current_year_total': '97.4',
#   'date': '2015-11-07',
#   'home_score_avg': '92.5',
#   'last_game': '94.0',
#   'last_three': '96.0',
#   'rank': '22',
#   'team': 'Dallas'},
#  {'away_score_avg': '105.5',
#   'current_year_total': '97.3',
#   'date': '2015-11-07',
#   'home_score_avg': '81.0',
#   'last_game': '104.0',
#   'last_three': '102.7',
#   'rank': '23',
#   'team': 'Denver'},
#  {'away_score_avg': '91.7',
#   'current_year_total': '96.7',
#   'date': '2015-11-07',
#   'home_score_avg': '101.7',
#   'last_game': '87.0',
#   'last_three': '91.7',
#   'rank': '24',
#   'team': 'Miami'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '95.6',
#   'date': '2015-11-07',
#   'home_score_avg': '90.7',
#   'last_game': '100.0',
#   'last_three': '93.3',
#   'rank': '25',
#   'team': 'Detroit'},
#  {'away_score_avg': '94.8',
#   'current_year_total': '94.2',
#   'date': '2015-11-07',
#   'home_score_avg': '92.0',
#   'last_game': '96.0',
#   'last_three': '95.0',
#   'rank': '26',
#   'team': 'Utah'},
#  {'away_score_avg': '96.5',
#   'current_year_total': '93.7',
#   'date': '2015-11-07',
#   'home_score_avg': '92.2',
#   'last_game': '90.0',
#   'last_three': '94.7',
#   'rank': '27',
#   'team': 'Indiana'},
#  {'away_score_avg': '95.0',
#   'current_year_total': '92.8',
#   'date': '2015-11-07',
#   'home_score_avg': '88.5',
#   'last_game': '96.0',
#   'last_three': '89.3',
#   'rank': '28',
#   'team': 'Memphis'},
#  {'away_score_avg': '84.3',
#   'current_year_total': '91.2',
#   'date': '2015-11-07',
#   'home_score_avg': '98.0',
#   'last_game': '98.0',
#   'last_three': '93.7',
#   'rank': '29',
#   'team': 'Brooklyn'},
#  {'away_score_avg': '94.7',
#   'current_year_total': '91.0',
#   'date': '2015-11-07',
#   'home_score_avg': '85.5',
#   'last_game': '102.0',
#   'last_three': '96.3',
#   'rank': '30',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '116.3',
#   'current_year_total': '115.7',
#   'date': '2015-11-08',
#   'home_score_avg': '115.2',
#   'last_game': '103.0',
#   'last_three': '111.3',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '114.0',
#   'current_year_total': '111.5',
#   'date': '2015-11-08',
#   'home_score_avg': '109.0',
#   'last_game': '98.0',
#   'last_three': '100.3',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '109.5',
#   'current_year_total': '107.3',
#   'date': '2015-11-08',
#   'home_score_avg': '106.2',
#   'last_game': '105.0',
#   'last_three': '105.0',
#   'rank': '3',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '109.0',
#   'current_year_total': '106.2',
#   'date': '2015-11-08',
#   'home_score_avg': '104.3',
#   'last_game': '104.0',
#   'last_three': '102.0',
#   'rank': '4',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '105.0',
#   'date': '2015-11-08',
#   'home_score_avg': '105.8',
#   'last_game': '94.0',
#   'last_three': '100.3',
#   'rank': '5',
#   'team': 'Sacramento'},
#  {'away_score_avg': '106.2',
#   'current_year_total': '103.9',
#   'date': '2015-11-08',
#   'home_score_avg': '101.5',
#   'last_game': '114.0',
#   'last_three': '112.0',
#   'rank': '6',
#   'team': 'Atlanta'},
#  {'away_score_avg': '102.0',
#   'current_year_total': '103.8',
#   'date': '2015-11-08',
#   'home_score_avg': '105.7',
#   'last_game': '115.0',
#   'last_three': '109.7',
#   'rank': '7',
#   'team': 'Portland'},
#  {'away_score_avg': '98.0',
#   'current_year_total': '103.6',
#   'date': '2015-11-08',
#   'home_score_avg': '105.0',
#   'last_game': '118.0',
#   'last_three': '101.0',
#   'rank': '8',
#   'team': 'Boston'},
#  {'away_score_avg': '102.2',
#   'current_year_total': '103.4',
#   'date': '2015-11-08',
#   'home_score_avg': '105.0',
#   'last_game': '105.0',
#   'last_three': '103.7',
#   'rank': '9',
#   'team': 'Orlando'},
#  {'away_score_avg': '104.7',
#   'current_year_total': '102.9',
#   'date': '2015-11-08',
#   'home_score_avg': '101.5',
#   'last_game': '109.0',
#   'last_three': '114.7',
#   'rank': '10',
#   'team': 'Houston'},
#  {'away_score_avg': '101.2',
#   'current_year_total': '102.8',
#   'date': '2015-11-08',
#   'home_score_avg': '106.0',
#   'last_game': '87.0',
#   'last_three': '97.3',
#   'rank': '11',
#   'team': 'Toronto'},
#  {'away_score_avg': '95.7',
#   'current_year_total': '102.7',
#   'date': '2015-11-08',
#   'home_score_avg': '109.7',
#   'last_game': '98.0',
#   'last_three': '102.3',
#   'rank': '12',
#   'team': 'New Orleans'},
#  {'away_score_avg': '100.8',
#   'current_year_total': '102.5',
#   'date': '2015-11-08',
#   'home_score_avg': '106.0',
#   'last_game': '99.0',
#   'last_three': '99.7',
#   'rank': '13',
#   'team': 'Washington'},
#  {'away_score_avg': '102.7',
#   'current_year_total': '102.3',
#   'date': '2015-11-08',
#   'home_score_avg': '102.0',
#   'last_game': '108.0',
#   'last_three': '103.7',
#   'rank': '14',
#   'team': 'Cleveland'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '102.0',
#   'date': '2015-11-08',
#   'home_score_avg': '103.8',
#   'last_game': '92.0',
#   'last_three': '102.0',
#   'rank': '15',
#   'team': 'Phoenix'},
#  {'away_score_avg': '97.5',
#   'current_year_total': '102.0',
#   'date': '2015-11-08',
#   'home_score_avg': '111.0',
#   'last_game': '94.0',
#   'last_three': '110.7',
#   'rank': '16',
#   'team': 'Charlotte'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '101.7',
#   'date': '2015-11-08',
#   'home_score_avg': '108.0',
#   'last_game': '114.0',
#   'last_three': '102.3',
#   'rank': '17',
#   'team': 'San Antonio'},
#  {'away_score_avg': '108.3',
#   'current_year_total': '100.3',
#   'date': '2015-11-08',
#   'home_score_avg': '92.3',
#   'last_game': '92.0',
#   'last_three': '87.3',
#   'rank': '18',
#   'team': 'New York'},
#  {'away_score_avg': '104.7',
#   'current_year_total': '100.0',
#   'date': '2015-11-08',
#   'home_score_avg': '96.5',
#   'last_game': '93.0',
#   'last_three': '100.7',
#   'rank': '19',
#   'team': 'Chicago'},
#  {'away_score_avg': '100.7',
#   'current_year_total': '99.0',
#   'date': '2015-11-08',
#   'home_score_avg': '97.3',
#   'last_game': '107.0',
#   'last_three': '97.3',
#   'rank': '20',
#   'team': 'Dallas'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '98.8',
#   'date': '2015-11-08',
#   'home_score_avg': '92.5',
#   'last_game': '102.0',
#   'last_three': '95.7',
#   'rank': '21',
#   'team': 'Minnesota'},
#  {'away_score_avg': '96.3',
#   'current_year_total': '97.7',
#   'date': '2015-11-08',
#   'home_score_avg': '98.8',
#   'last_game': '94.0',
#   'last_three': '94.7',
#   'rank': '22',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '105.5',
#   'current_year_total': '97.3',
#   'date': '2015-11-08',
#   'home_score_avg': '81.0',
#   'last_game': '104.0',
#   'last_three': '102.7',
#   'rank': '23',
#   'team': 'Denver'},
#  {'away_score_avg': '91.7',
#   'current_year_total': '96.7',
#   'date': '2015-11-08',
#   'home_score_avg': '101.7',
#   'last_game': '87.0',
#   'last_three': '91.7',
#   'rank': '24',
#   'team': 'Miami'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '95.6',
#   'date': '2015-11-08',
#   'home_score_avg': '90.7',
#   'last_game': '100.0',
#   'last_three': '93.3',
#   'rank': '25',
#   'team': 'Detroit'},
#  {'away_score_avg': '96.5',
#   'current_year_total': '93.7',
#   'date': '2015-11-08',
#   'home_score_avg': '92.2',
#   'last_game': '90.0',
#   'last_three': '94.7',
#   'rank': '26',
#   'team': 'Indiana'},
#  {'away_score_avg': '94.8',
#   'current_year_total': '93.3',
#   'date': '2015-11-08',
#   'home_score_avg': '90.5',
#   'last_game': '89.0',
#   'last_three': '92.3',
#   'rank': '27',
#   'team': 'Utah'},
#  {'away_score_avg': '94.7',
#   'current_year_total': '92.0',
#   'date': '2015-11-08',
#   'home_score_avg': '89.3',
#   'last_game': '97.0',
#   'last_three': '95.3',
#   'rank': '28',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '91.8',
#   'current_year_total': '90.9',
#   'date': '2015-11-08',
#   'home_score_avg': '88.5',
#   'last_game': '79.0',
#   'last_three': '92.7',
#   'rank': '29',
#   'team': 'Memphis'},
#  {'away_score_avg': '84.8',
#   'current_year_total': '90.4',
#   'date': '2015-11-08',
#   'home_score_avg': '98.0',
#   'last_game': '86.0',
#   'last_three': '90.3',
#   'rank': '30',
#   'team': 'Brooklyn'},
#  {'away_score_avg': '116.3',
#   'current_year_total': '115.7',
#   'date': '2015-11-09',
#   'home_score_avg': '115.2',
#   'last_game': '103.0',
#   'last_three': '111.3',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '114.0',
#   'current_year_total': '113.3',
#   'date': '2015-11-09',
#   'home_score_avg': '112.8',
#   'last_game': '124.0',
#   'last_three': '106.7',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '109.5',
#   'current_year_total': '107.3',
#   'date': '2015-11-09',
#   'home_score_avg': '106.2',
#   'last_game': '105.0',
#   'last_three': '105.0',
#   'rank': '3',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '105.0',
#   'date': '2015-11-09',
#   'home_score_avg': '105.8',
#   'last_game': '94.0',
#   'last_three': '100.3',
#   'rank': '4',
#   'team': 'Sacramento'},
#  {'away_score_avg': '104.3',
#   'current_year_total': '104.3',
#   'date': '2015-11-09',
#   'home_score_avg': '104.3',
#   'last_game': '95.0',
#   'last_three': '102.7',
#   'rank': '5',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '106.2',
#   'current_year_total': '103.9',
#   'date': '2015-11-09',
#   'home_score_avg': '101.5',
#   'last_game': '114.0',
#   'last_three': '112.0',
#   'rank': '6',
#   'team': 'Atlanta'},
#  {'away_score_avg': '102.0',
#   'current_year_total': '103.7',
#   'date': '2015-11-09',
#   'home_score_avg': '105.0',
#   'last_game': '103.0',
#   'last_three': '108.7',
#   'rank': '7',
#   'team': 'Portland'},
#  {'away_score_avg': '98.0',
#   'current_year_total': '103.6',
#   'date': '2015-11-09',
#   'home_score_avg': '105.0',
#   'last_game': '118.0',
#   'last_three': '101.0',
#   'rank': '8',
#   'team': 'Boston'},
#  {'away_score_avg': '102.2',
#   'current_year_total': '103.4',
#   'date': '2015-11-09',
#   'home_score_avg': '105.0',
#   'last_game': '105.0',
#   'last_three': '103.7',
#   'rank': '9',
#   'team': 'Orlando'},
#  {'away_score_avg': '104.7',
#   'current_year_total': '102.9',
#   'date': '2015-11-09',
#   'home_score_avg': '101.5',
#   'last_game': '109.0',
#   'last_three': '114.7',
#   'rank': '10',
#   'team': 'Houston'},
#  {'away_score_avg': '95.7',
#   'current_year_total': '102.7',
#   'date': '2015-11-09',
#   'home_score_avg': '109.7',
#   'last_game': '98.0',
#   'last_three': '102.3',
#   'rank': '11',
#   'team': 'New Orleans'},
#  {'away_score_avg': '100.8',
#   'current_year_total': '102.5',
#   'date': '2015-11-09',
#   'home_score_avg': '106.0',
#   'last_game': '99.0',
#   'last_three': '99.7',
#   'rank': '12',
#   'team': 'Washington'},
#  {'away_score_avg': '102.7',
#   'current_year_total': '102.1',
#   'date': '2015-11-09',
#   'home_score_avg': '101.8',
#   'last_game': '101.0',
#   'last_three': '101.7',
#   'rank': '13',
#   'team': 'Cleveland'},
#  {'away_score_avg': '100.0',
#   'current_year_total': '102.1',
#   'date': '2015-11-09',
#   'home_score_avg': '103.8',
#   'last_game': '103.0',
#   'last_three': '104.3',
#   'rank': '14',
#   'team': 'Phoenix'},
#  {'away_score_avg': '97.5',
#   'current_year_total': '102.0',
#   'date': '2015-11-09',
#   'home_score_avg': '111.0',
#   'last_game': '94.0',
#   'last_three': '110.7',
#   'rank': '15',
#   'team': 'Charlotte'},
#  {'away_score_avg': '98.5',
#   'current_year_total': '101.7',
#   'date': '2015-11-09',
#   'home_score_avg': '108.0',
#   'last_game': '114.0',
#   'last_three': '102.3',
#   'rank': '16',
#   'team': 'San Antonio'},
#  {'away_score_avg': '108.3',
#   'current_year_total': '100.1',
#   'date': '2015-11-09',
#   'home_score_avg': '94.0',
#   'last_game': '99.0',
#   'last_three': '92.3',
#   'rank': '17',
#   'team': 'New York'},
#  {'away_score_avg': '104.7',
#   'current_year_total': '100.0',
#   'date': '2015-11-09',
#   'home_score_avg': '96.5',
#   'last_game': '93.0',
#   'last_three': '100.7',
#   'rank': '18',
#   'team': 'Chicago'},
#  {'away_score_avg': '108.7',
#   'current_year_total': '99.7',
#   'date': '2015-11-09',
#   'home_score_avg': '90.7',
#   'last_game': '120.0',
#   'last_three': '100.7',
#   'rank': '19',
#   'team': 'Detroit'},
#  {'away_score_avg': '96.2',
#   'current_year_total': '99.0',
#   'date': '2015-11-09',
#   'home_score_avg': '106.0',
#   'last_game': '76.0',
#   'last_three': '88.7',
#   'rank': '20',
#   'team': 'Toronto'},
#  {'away_score_avg': '100.7',
#   'current_year_total': '99.0',
#   'date': '2015-11-09',
#   'home_score_avg': '97.3',
#   'last_game': '107.0',
#   'last_three': '97.3',
#   'rank': '21',
#   'team': 'Dallas'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '98.8',
#   'date': '2015-11-09',
#   'home_score_avg': '92.5',
#   'last_game': '102.0',
#   'last_three': '95.7',
#   'rank': '22',
#   'team': 'Minnesota'},
#  {'away_score_avg': '96.3',
#   'current_year_total': '97.7',
#   'date': '2015-11-09',
#   'home_score_avg': '98.8',
#   'last_game': '94.0',
#   'last_three': '94.7',
#   'rank': '23',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '105.5',
#   'current_year_total': '97.3',
#   'date': '2015-11-09',
#   'home_score_avg': '81.0',
#   'last_game': '104.0',
#   'last_three': '102.7',
#   'rank': '24',
#   'team': 'Denver'},
#  {'away_score_avg': '91.7',
#   'current_year_total': '96.6',
#   'date': '2015-11-09',
#   'home_score_avg': '100.2',
#   'last_game': '96.0',
#   'last_three': '93.0',
#   'rank': '25',
#   'team': 'Miami'},
#  {'away_score_avg': '96.7',
#   'current_year_total': '94.1',
#   'date': '2015-11-09',
#   'home_score_avg': '92.2',
#   'last_game': '97.0',
#   'last_three': '95.7',
#   'rank': '26',
#   'team': 'Indiana'},
#  {'away_score_avg': '94.8',
#   'current_year_total': '93.3',
#   'date': '2015-11-09',
#   'home_score_avg': '90.5',
#   'last_game': '89.0',
#   'last_three': '92.3',
#   'rank': '27',
#   'team': 'Utah'},
#  {'away_score_avg': '94.7',
#   'current_year_total': '92.0',
#   'date': '2015-11-09',
#   'home_score_avg': '89.3',
#   'last_game': '97.0',
#   'last_three': '95.3',
#   'rank': '28',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '91.8',
#   'current_year_total': '90.9',
#   'date': '2015-11-09',
#   'home_score_avg': '88.5',
#   'last_game': '79.0',
#   'last_three': '92.7',
#   'rank': '29',
#   'team': 'Memphis'},
#  {'away_score_avg': '84.8',
#   'current_year_total': '90.4',
#   'date': '2015-11-09',
#   'home_score_avg': '98.0',
#   'last_game': '86.0',
#   'last_three': '90.3',
#   'rank': '30',
#   'team': 'Brooklyn'},
#  {'away_score_avg': '116.3',
#   'current_year_total': '114.9',
#   'date': '2015-11-10',
#   'home_score_avg': '114.0',
#   'last_game': '109.0',
#   'last_three': '110.3',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '114.0',
#   'current_year_total': '113.3',
#   'date': '2015-11-10',
#   'home_score_avg': '112.8',
#   'last_game': '124.0',
#   'last_three': '106.7',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '109.5',
#   'current_year_total': '105.4',
#   'date': '2015-11-10',
#   'home_score_avg': '103.8',
#   'last_game': '94.0',
#   'last_three': '102.3',
#   'rank': '3',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '104.3',
#   'current_year_total': '104.3',
#   'date': '2015-11-10',
#   'home_score_avg': '104.3',
#   'last_game': '95.0',
#   'last_three': '102.7',
#   'rank': '4',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '106.2',
#   'current_year_total': '104.2',
#   'date': '2015-11-10',
#   'home_score_avg': '102.6',
#   'last_game': '107.0',
#   'last_three': '114.0',
#   'rank': '5',
#   'team': 'Atlanta'},
#  {'away_score_avg': '102.5',
#   'current_year_total': '103.8',
#   'date': '2015-11-10',
#   'home_score_avg': '105.0',
#   'last_game': '104.0',
#   'last_three': '107.3',
#   'rank': '6',
#   'team': 'Portland'},
#  {'away_score_avg': '98.0',
#   'current_year_total': '103.6',
#   'date': '2015-11-10',
#   'home_score_avg': '105.0',
#   'last_game': '118.0',
#   'last_three': '101.0',
#   'rank': '7',
#   'team': 'Boston'},
#  {'away_score_avg': '103.0',
#   'current_year_total': '102.9',
#   'date': '2015-11-10',
#   'home_score_avg': '102.8',
#   'last_game': '88.0',
#   'last_three': '97.3',
#   'rank': '8',
#   'team': 'Sacramento'},
#  {'away_score_avg': '104.7',
#   'current_year_total': '102.9',
#   'date': '2015-11-10',
#   'home_score_avg': '101.5',
#   'last_game': '109.0',
#   'last_three': '114.7',
#   'rank': '9',
#   'team': 'Houston'},
#  {'away_score_avg': '95.7',
#   'current_year_total': '102.7',
#   'date': '2015-11-10',
#   'home_score_avg': '109.7',
#   'last_game': '98.0',
#   'last_three': '102.3',
#   'rank': '10',
#   'team': 'New Orleans'},
#  {'away_score_avg': '100.8',
#   'current_year_total': '102.5',
#   'date': '2015-11-10',
#   'home_score_avg': '106.0',
#   'last_game': '99.0',
#   'last_three': '99.7',
#   'rank': '11',
#   'team': 'Washington'},
#  {'away_score_avg': '100.0',
#   'current_year_total': '102.3',
#   'date': '2015-11-10',
#   'home_score_avg': '108.0',
#   'last_game': '106.0',
#   'last_three': '106.3',
#   'rank': '12',
#   'team': 'San Antonio'},
#  {'away_score_avg': '102.7',
#   'current_year_total': '102.1',
#   'date': '2015-11-10',
#   'home_score_avg': '101.8',
#   'last_game': '101.0',
#   'last_three': '101.7',
#   'rank': '13',
#   'team': 'Cleveland'},
#  {'away_score_avg': '100.0',
#   'current_year_total': '102.1',
#   'date': '2015-11-10',
#   'home_score_avg': '103.8',
#   'last_game': '103.0',
#   'last_three': '104.3',
#   'rank': '14',
#   'team': 'Phoenix'},
#  {'away_score_avg': '97.5',
#   'current_year_total': '102.0',
#   'date': '2015-11-10',
#   'home_score_avg': '111.0',
#   'last_game': '94.0',
#   'last_three': '110.7',
#   'rank': '15',
#   'team': 'Charlotte'},
#  {'away_score_avg': '106.5',
#   'current_year_total': '101.8',
#   'date': '2015-11-10',
#   'home_score_avg': '92.5',
#   'last_game': '117.0',
#   'last_three': '101.0',
#   'rank': '16',
#   'team': 'Minnesota'},
#  {'away_score_avg': '106.2',
#   'current_year_total': '101.4',
#   'date': '2015-11-10',
#   'home_score_avg': '96.5',
#   'last_game': '111.0',
#   'last_three': '102.7',
#   'rank': '17',
#   'team': 'Chicago'},
#  {'away_score_avg': '98.6',
#   'current_year_total': '101.0',
#   'date': '2015-11-10',
#   'home_score_avg': '105.0',
#   'last_game': '84.0',
#   'last_three': '93.7',
#   'rank': '18',
#   'team': 'Orlando'},
#  {'away_score_avg': '108.3',
#   'current_year_total': '100.1',
#   'date': '2015-11-10',
#   'home_score_avg': '94.0',
#   'last_game': '99.0',
#   'last_three': '92.3',
#   'rank': '19',
#   'team': 'New York'},
#  {'away_score_avg': '96.2',
#   'current_year_total': '99.0',
#   'date': '2015-11-10',
#   'home_score_avg': '106.0',
#   'last_game': '76.0',
#   'last_three': '88.7',
#   'rank': '20',
#   'team': 'Toronto'},
#  {'away_score_avg': '105.2',
#   'current_year_total': '99.0',
#   'date': '2015-11-10',
#   'home_score_avg': '90.7',
#   'last_game': '95.0',
#   'last_three': '105.0',
#   'rank': '21',
#   'team': 'Detroit'},
#  {'away_score_avg': '100.7',
#   'current_year_total': '99.0',
#   'date': '2015-11-10',
#   'home_score_avg': '97.3',
#   'last_game': '107.0',
#   'last_three': '97.3',
#   'rank': '22',
#   'team': 'Dallas'},
#  {'away_score_avg': '105.5',
#   'current_year_total': '98.9',
#   'date': '2015-11-10',
#   'home_score_avg': '90.0',
#   'last_game': '108.0',
#   'last_three': '98.7',
#   'rank': '23',
#   'team': 'Denver'},
#  {'away_score_avg': '96.3',
#   'current_year_total': '97.7',
#   'date': '2015-11-10',
#   'home_score_avg': '98.8',
#   'last_game': '94.0',
#   'last_three': '94.7',
#   'rank': '24',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '91.7',
#   'current_year_total': '96.6',
#   'date': '2015-11-10',
#   'home_score_avg': '100.2',
#   'last_game': '96.0',
#   'last_three': '93.0',
#   'rank': '25',
#   'team': 'Miami'},
#  {'away_score_avg': '96.7',
#   'current_year_total': '94.5',
#   'date': '2015-11-10',
#   'home_score_avg': '93.2',
#   'last_game': '97.0',
#   'last_three': '94.7',
#   'rank': '26',
#   'team': 'Indiana'},
#  {'away_score_avg': '94.8',
#   'current_year_total': '93.3',
#   'date': '2015-11-10',
#   'home_score_avg': '90.5',
#   'last_game': '89.0',
#   'last_three': '92.3',
#   'rank': '27',
#   'team': 'Utah'},
#  {'away_score_avg': '94.7',
#   'current_year_total': '91.4',
#   'date': '2015-11-10',
#   'home_score_avg': '89.0',
#   'last_game': '88.0',
#   'last_three': '95.7',
#   'rank': '28',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '91.8',
#   'current_year_total': '91.0',
#   'date': '2015-11-10',
#   'home_score_avg': '88.5',
#   'last_game': '92.0',
#   'last_three': '89.0',
#   'rank': '29',
#   'team': 'Memphis'},
#  {'away_score_avg': '84.8',
# ...
#   'date': '2015-12-03',
#   'home_score_avg': '102.2',
#   'last_game': '127.0',
#   'last_three': '108.7',
#   'rank': '21',
#   'team': 'Detroit'},
#  {'away_score_avg': '95.9',
#   'current_year_total': '97.3',
#   'date': '2015-12-03',
#   'home_score_avg': '99.6',
#   'last_game': '108.0',
#   'last_three': '100.7',
#   'rank': '22',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '96.2',
#   'current_year_total': '97.1',
#   'date': '2015-12-03',
#   'home_score_avg': '98.1',
#   'last_game': '113.0',
#   'last_three': '102.0',
#   'rank': '23',
#   'team': 'Memphis'},
#  {'away_score_avg': '99.8',
#   'current_year_total': '97.0',
#   'date': '2015-12-03',
#   'home_score_avg': '94.5',
#   'last_game': '99.0',
#   'last_three': '96.0',
#   'rank': '24',
#   'team': 'New York'},
#  {'away_score_avg': '90.6',
#   'current_year_total': '96.2',
#   'date': '2015-12-03',
#   'home_score_avg': '98.8',
#   'last_game': '95.0',
#   'last_three': '91.0',
#   'rank': '25',
#   'team': 'Miami'},
#  {'away_score_avg': '96.1',
#   'current_year_total': '96.2',
#   'date': '2015-12-03',
#   'home_score_avg': '96.2',
#   'last_game': '90.0',
#   'last_three': '81.7',
#   'rank': '26',
#   'team': 'Denver'},
#  {'away_score_avg': '96.9',
#   'current_year_total': '96.0',
#   'date': '2015-12-03',
#   'home_score_avg': '94.5',
#   'last_game': '103.0',
#   'last_three': '102.0',
#   'rank': '27',
#   'team': 'Utah'},
#  {'away_score_avg': '95.1',
#   'current_year_total': '95.7',
#   'date': '2015-12-03',
#   'home_score_avg': '96.6',
#   'last_game': '94.0',
#   'last_three': '89.7',
#   'rank': '28',
#   'team': 'Brooklyn'},
#  {'away_score_avg': '90.5',
#   'current_year_total': '95.3',
#   'date': '2015-12-03',
#   'home_score_avg': '100.6',
#   'last_game': '70.0',
#   'last_three': '81.3',
#   'rank': '29',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '90.9',
#   'current_year_total': '91.2',
#   'date': '2015-12-03',
#   'home_score_avg': '91.6',
#   'last_game': '87.0',
#   'last_three': '91.3',
#   'rank': '30',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '117.7',
#   'current_year_total': '115.3',
#   'date': '2015-12-04',
#   'home_score_avg': '112.9',
#   'last_game': '116.0',
#   'last_three': '114.0',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '110.9',
#   'current_year_total': '108.2',
#   'date': '2015-12-04',
#   'home_score_avg': '106.2',
#   'last_game': '95.0',
#   'last_three': '99.3',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '103.8',
#   'current_year_total': '106.3',
#   'date': '2015-12-04',
#   'home_score_avg': '108.5',
#   'last_game': '122.0',
#   'last_three': '106.7',
#   'rank': '3',
#   'team': 'Phoenix'},
#  {'away_score_avg': '106.4',
#   'current_year_total': '104.8',
#   'date': '2015-12-04',
#   'home_score_avg': '103.5',
#   'last_game': '97.0',
#   'last_three': '103.3',
#   'rank': '4',
#   'team': 'Sacramento'},
#  {'away_score_avg': '105.5',
#   'current_year_total': '102.7',
#   'date': '2015-12-04',
#   'home_score_avg': '101.5',
#   'last_game': '91.0',
#   'last_three': '100.0',
#   'rank': '5',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '101.8',
#   'current_year_total': '102.6',
#   'date': '2015-12-04',
#   'home_score_avg': '103.4',
#   'last_game': '114.0',
#   'last_three': '103.3',
#   'rank': '6',
#   'team': 'Boston'},
#  {'away_score_avg': '104.3',
#   'current_year_total': '102.4',
#   'date': '2015-12-04',
#   'home_score_avg': '100.0',
#   'last_game': '111.0',
#   'last_three': '107.0',
#   'rank': '7',
#   'team': 'Indiana'},
#  {'away_score_avg': '97.9',
#   'current_year_total': '102.3',
#   'date': '2015-12-04',
#   'home_score_avg': '105.1',
#   'last_game': '99.0',
#   'last_three': '92.0',
#   'rank': '8',
#   'team': 'Charlotte'},
#  {'away_score_avg': '102.4',
#   'current_year_total': '102.2',
#   'date': '2015-12-04',
#   'home_score_avg': '102.0',
#   'last_game': '108.0',
#   'last_three': '109.7',
#   'rank': '9',
#   'team': 'Houston'},
#  {'away_score_avg': '99.5',
#   'current_year_total': '102.1',
#   'date': '2015-12-04',
#   'home_score_avg': '104.1',
#   'last_game': '85.0',
#   'last_three': '90.0',
#   'rank': '10',
#   'team': 'Cleveland'},
#  {'away_score_avg': '98.1',
#   'current_year_total': '101.8',
#   'date': '2015-12-04',
#   'home_score_avg': '105.4',
#   'last_game': '123.0',
#   'last_three': '107.3',
#   'rank': '11',
#   'team': 'Portland'},
#  {'away_score_avg': '99.3',
#   'current_year_total': '101.6',
#   'date': '2015-12-04',
#   'home_score_avg': '103.7',
#   'last_game': '103.0',
#   'last_three': '103.0',
#   'rank': '12',
#   'team': 'Orlando'},
#  {'away_score_avg': '95.8',
#   'current_year_total': '101.6',
#   'date': '2015-12-04',
#   'home_score_avg': '109.6',
#   'last_game': '101.0',
#   'last_three': '97.3',
#   'rank': '13',
#   'team': 'New Orleans'},
#  {'away_score_avg': '100.2',
#   'current_year_total': '101.6',
#   'date': '2015-12-04',
#   'home_score_avg': '102.8',
#   'last_game': '86.0',
#   'last_three': '93.3',
#   'rank': '14',
#   'team': 'Atlanta'},
#  {'away_score_avg': '101.8',
#   'current_year_total': '100.8',
#   'date': '2015-12-04',
#   'home_score_avg': '99.1',
#   'last_game': '115.0',
#   'last_three': '101.7',
#   'rank': '15',
#   'team': 'Dallas'},
#  {'away_score_avg': '103.7',
#   'current_year_total': '100.7',
#   'date': '2015-12-04',
#   'home_score_avg': '97.8',
#   'last_game': '93.0',
#   'last_three': '97.7',
#   'rank': '16',
#   'team': 'Minnesota'},
#  {'away_score_avg': '97.9',
#   'current_year_total': '100.2',
#   'date': '2015-12-04',
#   'home_score_avg': '104.4',
#   'last_game': '105.0',
#   'last_three': '101.0',
#   'rank': '17',
#   'team': 'Toronto'},
#  {'away_score_avg': '95.2',
#   'current_year_total': '99.4',
#   'date': '2015-12-04',
#   'home_score_avg': '103.5',
#   'last_game': '104.0',
#   'last_three': '94.3',
#   'rank': '18',
#   'team': 'Washington'},
#  {'away_score_avg': '100.9',
#   'current_year_total': '98.9',
#   'date': '2015-12-04',
#   'home_score_avg': '96.9',
#   'last_game': '99.0',
#   'last_three': '94.3',
#   'rank': '19',
#   'team': 'Chicago'},
#  {'away_score_avg': '98.6',
#   'current_year_total': '98.8',
#   'date': '2015-12-04',
#   'home_score_avg': '99.1',
#   'last_game': '103.0',
#   'last_three': '95.7',
#   'rank': '20',
#   'team': 'San Antonio'},
#  {'away_score_avg': '95.3',
#   'current_year_total': '98.2',
#   'date': '2015-12-04',
#   'home_score_avg': '102.2',
#   'last_game': '127.0',
#   'last_three': '108.7',
#   'rank': '21',
#   'team': 'Detroit'},
#  {'away_score_avg': '95.9',
#   'current_year_total': '97.3',
#   'date': '2015-12-04',
#   'home_score_avg': '99.6',
#   'last_game': '108.0',
#   'last_three': '100.7',
#   'rank': '22',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '99.8',
#   'current_year_total': '97.0',
#   'date': '2015-12-04',
#   'home_score_avg': '94.5',
#   'last_game': '99.0',
#   'last_three': '96.0',
#   'rank': '23',
#   'team': 'New York'},
#  {'away_score_avg': '97.0',
#   'current_year_total': '96.7',
#   'date': '2015-12-04',
#   'home_score_avg': '96.2',
#   'last_game': '106.0',
#   'last_three': '90.0',
#   'rank': '24',
#   'team': 'Denver'},
#  {'away_score_avg': '96.2',
#   'current_year_total': '96.4',
#   'date': '2015-12-04',
#   'home_score_avg': '96.6',
#   'last_game': '83.0',
#   'last_three': '96.0',
#   'rank': '25',
#   'team': 'Memphis'},
#  {'away_score_avg': '90.6',
#   'current_year_total': '96.3',
#   'date': '2015-12-04',
#   'home_score_avg': '98.7',
#   'last_game': '97.0',
#   'last_three': '96.3',
#   'rank': '26',
#   'team': 'Miami'},
#  {'away_score_avg': '96.9',
#   'current_year_total': '95.9',
#   'date': '2015-12-04',
#   'home_score_avg': '94.4',
#   'last_game': '94.0',
#   'last_three': '99.3',
#   'rank': '27',
#   'team': 'Utah'},
#  {'away_score_avg': '95.1',
#   'current_year_total': '95.7',
#   'date': '2015-12-04',
#   'home_score_avg': '96.6',
#   'last_game': '94.0',
#   'last_three': '89.7',
#   'rank': '28',
#   'team': 'Brooklyn'},
#  {'away_score_avg': '90.5',
#   'current_year_total': '95.3',
#   'date': '2015-12-04',
#   'home_score_avg': '100.6',
#   'last_game': '70.0',
#   'last_three': '81.3',
#   'rank': '29',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '90.9',
#   'current_year_total': '91.2',
#   'date': '2015-12-04',
#   'home_score_avg': '91.6',
#   'last_game': '87.0',
#   'last_three': '91.3',
#   'rank': '30',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '117.7',
#   'current_year_total': '115.3',
#   'date': '2015-12-05',
#   'home_score_avg': '112.9',
#   'last_game': '116.0',
#   'last_three': '114.0',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '110.9',
#   'current_year_total': '108.2',
#   'date': '2015-12-05',
#   'home_score_avg': '106.2',
#   'last_game': '95.0',
#   'last_three': '99.3',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '104.0',
#   'current_year_total': '106.2',
#   'date': '2015-12-05',
#   'home_score_avg': '108.5',
#   'last_game': '106.0',
#   'last_three': '106.3',
#   'rank': '3',
#   'team': 'Phoenix'},
#  {'away_score_avg': '106.4',
#   'current_year_total': '104.8',
#   'date': '2015-12-05',
#   'home_score_avg': '103.5',
#   'last_game': '97.0',
#   'last_three': '103.3',
#   'rank': '4',
#   'team': 'Sacramento'},
#  {'away_score_avg': '105.5',
#   'current_year_total': '102.7',
#   'date': '2015-12-05',
#   'home_score_avg': '101.5',
#   'last_game': '91.0',
#   'last_three': '100.0',
#   'rank': '5',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '101.8',
#   'current_year_total': '102.6',
#   'date': '2015-12-05',
#   'home_score_avg': '103.4',
#   'last_game': '114.0',
#   'last_three': '103.3',
#   'rank': '6',
#   'team': 'Boston'},
#  {'away_score_avg': '104.3',
#   'current_year_total': '102.4',
#   'date': '2015-12-05',
#   'home_score_avg': '100.0',
#   'last_game': '111.0',
#   'last_three': '107.0',
#   'rank': '7',
#   'team': 'Indiana'},
#  {'away_score_avg': '100.4',
#   'current_year_total': '102.4',
#   'date': '2015-12-05',
#   'home_score_avg': '104.1',
#   'last_game': '108.0',
#   'last_three': '94.3',
#   'rank': '8',
#   'team': 'Cleveland'},
#  {'away_score_avg': '97.9',
#   'current_year_total': '102.3',
#   'date': '2015-12-05',
#   'home_score_avg': '105.1',
#   'last_game': '99.0',
#   'last_three': '92.0',
#   'rank': '9',
#   'team': 'Charlotte'},
#  {'away_score_avg': '95.8',
#   'current_year_total': '102.2',
#   'date': '2015-12-05',
#   'home_score_avg': '110.1',
#   'last_game': '114.0',
#   'last_three': '106.3',
#   'rank': '10',
#   'team': 'New Orleans'},
#  {'away_score_avg': '102.1',
#   'current_year_total': '102.0',
#   'date': '2015-12-05',
#   'home_score_avg': '102.0',
#   'last_game': '100.0',
#   'last_three': '104.3',
#   'rank': '11',
#   'team': 'Houston'},
#  {'away_score_avg': '98.1',
#   'current_year_total': '101.8',
#   'date': '2015-12-05',
#   'home_score_avg': '105.4',
#   'last_game': '123.0',
#   'last_three': '107.3',
#   'rank': '12',
#   'team': 'Portland'},
#  {'away_score_avg': '99.3',
#   'current_year_total': '101.6',
#   'date': '2015-12-05',
#   'home_score_avg': '103.7',
#   'last_game': '103.0',
#   'last_three': '103.0',
#   'rank': '13',
#   'team': 'Orlando'},
#  {'away_score_avg': '100.2',
#   'current_year_total': '101.5',
#   'date': '2015-12-05',
#   'home_score_avg': '102.6',
#   'last_game': '100.0',
#   'last_three': '97.3',
#   'rank': '14',
#   'team': 'Atlanta'},
#  {'away_score_avg': '103.7',
#   'current_year_total': '100.7',
#   'date': '2015-12-05',
#   'home_score_avg': '97.8',
#   'last_game': '93.0',
#   'last_three': '97.7',
#   'rank': '15',
#   'team': 'Minnesota'},
#  {'away_score_avg': '101.8',
#   'current_year_total': '100.5',
#   'date': '2015-12-05',
#   'home_score_avg': '98.8',
#   'last_game': '96.0',
#   'last_three': '103.0',
#   'rank': '16',
#   'team': 'Dallas'},
#  {'away_score_avg': '97.9',
#   'current_year_total': '100.2',
#   'date': '2015-12-05',
#   'home_score_avg': '104.4',
#   'last_game': '105.0',
#   'last_three': '101.0',
#   'rank': '17',
#   'team': 'Toronto'},
#  {'away_score_avg': '95.2',
#   'current_year_total': '99.9',
#   'date': '2015-12-05',
#   'home_score_avg': '104.1',
#   'last_game': '109.0',
#   'last_three': '103.3',
#   'rank': '18',
#   'team': 'Washington'},
#  {'away_score_avg': '100.9',
#   'current_year_total': '98.9',
#   'date': '2015-12-05',
#   'home_score_avg': '96.9',
#   'last_game': '99.0',
#   'last_three': '94.3',
#   'rank': '19',
#   'team': 'Chicago'},
#  {'away_score_avg': '98.6',
#   'current_year_total': '98.8',
#   'date': '2015-12-05',
#   'home_score_avg': '99.1',
#   'last_game': '103.0',
#   'last_three': '95.7',
#   'rank': '20',
#   'team': 'San Antonio'},
#  {'away_score_avg': '95.3',
#   'current_year_total': '98.4',
#   'date': '2015-12-05',
#   'home_score_avg': '102.2',
#   'last_game': '102.0',
#   'last_three': '115.0',
#   'rank': '21',
#   'team': 'Detroit'},
#  {'away_score_avg': '99.8',
#   'current_year_total': '97.5',
#   'date': '2015-12-05',
#   'home_score_avg': '95.7',
#   'last_game': '108.0',
#   'last_three': '106.0',
#   'rank': '22',
#   'team': 'New York'},
#  {'away_score_avg': '95.2',
#   'current_year_total': '96.8',
#   'date': '2015-12-05',
#   'home_score_avg': '99.6',
#   'last_game': '87.0',
#   'last_three': '95.3',
#   'rank': '23',
#   'team': 'LA Lakers'},
#  {'away_score_avg': '97.0',
#   'current_year_total': '96.7',
#   'date': '2015-12-05',
#   'home_score_avg': '96.2',
#   'last_game': '106.0',
#   'last_three': '90.0',
#   'rank': '24',
#   'team': 'Denver'},
#  {'away_score_avg': '96.2',
#   'current_year_total': '96.4',
#   'date': '2015-12-05',
#   'home_score_avg': '96.6',
#   'last_game': '83.0',
#   'last_three': '96.0',
#   'rank': '25',
#   'team': 'Memphis'},
#  {'away_score_avg': '90.6',
#   'current_year_total': '96.3',
#   'date': '2015-12-05',
#   'home_score_avg': '98.7',
#   'last_game': '97.0',
#   'last_three': '96.3',
#   'rank': '26',
#   'team': 'Miami'},
#  {'away_score_avg': '96.9',
#   'current_year_total': '95.9',
#   'date': '2015-12-05',
#   'home_score_avg': '94.4',
#   'last_game': '94.0',
#   'last_three': '99.3',
#   'rank': '27',
#   'team': 'Utah'},
#  {'away_score_avg': '94.8',
#   'current_year_total': '95.4',
#   'date': '2015-12-05',
#   'home_score_avg': '96.6',
#   'last_game': '91.0',
#   'last_three': '90.7',
#   'rank': '28',
#   'team': 'Brooklyn'},
#  {'away_score_avg': '90.9',
#   'current_year_total': '95.2',
#   'date': '2015-12-05',
#   'home_score_avg': '100.6',
#   'last_game': '95.0',
#   'last_three': '85.7',
#   'rank': '29',
#   'team': 'Milwaukee'},
#  {'away_score_avg': '90.9',
#   'current_year_total': '91.2',
#   'date': '2015-12-05',
#   'home_score_avg': '91.6',
#   'last_game': '87.0',
#   'last_three': '91.3',
#   'rank': '30',
#   'team': 'Philadelphia'},
#  {'away_score_avg': '117.2',
#   'current_year_total': '115.1',
#   'date': '2015-12-06',
#   'home_score_avg': '112.9',
#   'last_game': '112.0',
#   'last_three': '111.3',
#   'rank': '1',
#   'team': 'Golden State'},
#  {'away_score_avg': '110.9',
#   'current_year_total': '108.2',
#   'date': '2015-12-06',
#   'home_score_avg': '106.2',
#   'last_game': '95.0',
#   'last_three': '99.3',
#   'rank': '2',
#   'team': 'Okla City'},
#  {'away_score_avg': '104.0',
#   'current_year_total': '106.2',
#   'date': '2015-12-06',
#   'home_score_avg': '108.5',
#   'last_game': '106.0',
#   'last_three': '106.3',
#   'rank': '3',
#   'team': 'Phoenix'},
#  {'away_score_avg': '107.1',
#   'current_year_total': '105.2',
#   'date': '2015-12-06',
#   'home_score_avg': '103.5',
#   'last_game': '113.0',
#   'last_three': '107.3',
#   'rank': '4',
#   'team': 'Sacramento'},
#  {'away_score_avg': '105.6',
#   'current_year_total': '103.3',
#   'date': '2015-12-06',
#   'home_score_avg': '100.0',
#   'last_game': '119.0',
#   'last_three': '111.0',
#   'rank': '5',
#   'team': 'Indiana'},
#  {'away_score_avg': '102.1',
#   'current_year_total': '102.9',
#   'date': '2015-12-06',
#   'home_score_avg': '103.4',
#   'last_game': '120.0',
#   'last_three': '109.3',
#   'rank': '6',
#   'team': 'Houston'},
#  {'away_score_avg': '102.1',
#   'current_year_total': '102.8',
#   'date': '2015-12-06',
#   'home_score_avg': '103.4',
#   'last_game': '105.0',
#   'last_three': '108.0',
#   'rank': '7',
#   'team': 'Boston'},
#  {'away_score_avg': '105.5',
#   'current_year_total': '102.8',
#   'date': '2015-12-06',
#   'home_score_avg': '101.6',
#   'last_game': '103.0',
#   'last_three': '98.7',
#   'rank': '8',
#   'team': 'LA Clippers'},
#  {'away_score_avg': '98.4',
#   'current_year_total': '102.3',
#   'date': '2015-12-06',
#   'home_score_avg': '105.1',
#   'last_game': '102.0',
#   'last_three': '96.0',
#   'rank': '9',
#   'team': 'Charlotte'},
#  {'away_score_avg': '95.8',
#   'current_year_total': '102.2',
#   'date': '2015-12-06',
#   'home_score_avg': '110.1',
#   'last_game': '114.0',
#   'last_three': '106.3',
#   'rank': '10',
#   'team': 'New Orleans'},
#  ...]

# %%
pd.DataFrame.from_dict(data)
# Out:
#             date rank          team current_year_total last_three last_game  \
# 0     2015-11-03    1  Golden State              119.0      121.7     119.0
# 1     2015-11-03    2     Okla City              118.2      120.3     105.0
# 2     2015-11-03    3    Sacramento              115.0      115.0     109.0
# 3     2015-11-03    4       Toronto              108.3      108.3     106.0
# 4     2015-11-03    5   LA Clippers              107.8      106.7     102.0
# ...          ...  ...           ...                ...        ...       ...
# 4885  2016-04-13   26      Brooklyn               98.7      105.0     111.0
# 4886  2016-04-13   27      New York               98.4       96.0      90.0
# 4887  2016-04-13   28          Utah               97.7       97.0      92.0
# 4888  2016-04-13   29  Philadelphia               97.3      102.7      98.0
# 4889  2016-04-13   30     LA Lakers               97.3       97.0      79.0
#
#      home_score_avg away_score_avg
# 0             115.0          123.0
# 1             114.5          122.0
# 2             118.0          109.0
# 3             106.0          113.0
# 4             106.7          111.0
# ...             ...            ...
# 4885           99.0           98.4
# 4886           98.8           97.9
# 4887           98.6           96.8
# 4888           98.1           96.5
# 4889           96.7           97.9
#
# [4890 rows x 8 columns]

# %%
# get every season into one df

# %%
start_dt = date(2016, 11, 1)             
end_dt = date(2017,4,12)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)

# %%
pd.DataFrame.from_dict(data)
# Out:
#             date rank          team current_year_total last_three last_game  \
# 0     2015-11-03    1  Golden State              119.0      121.7     119.0
# 1     2015-11-03    2     Okla City              118.2      120.3     105.0
# 2     2015-11-03    3    Sacramento              115.0      115.0     109.0
# 3     2015-11-03    4       Toronto              108.3      108.3     106.0
# 4     2015-11-03    5   LA Clippers              107.8      106.7     102.0
# ...          ...  ...           ...                ...        ...       ...
# 9775  2017-04-12   26       Detroit              101.2      106.0     101.0
# 9776  2017-04-12   27       Orlando              100.9      100.7      75.0
# 9777  2017-04-12   28          Utah              100.7      103.7     105.0
# 9778  2017-04-12   29       Memphis              100.6       97.0      90.0
# 9779  2017-04-12   30        Dallas               97.9       97.0      91.0
#
#      home_score_avg away_score_avg
# 0             115.0          123.0
# 1             114.5          122.0
# 2             118.0          109.0
# 3             106.0          113.0
# 4             106.7          111.0
# ...             ...            ...
# 9775          103.0           99.5
# 9776           99.9          101.9
# 9777          101.1          100.3
# 9778           99.4          101.7
# 9779           99.4           96.4
#
# [9780 rows x 8 columns]

# %%
start_dt = date(2017, 10, 24)             
end_dt = date(2018,4,11)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)

# %%
pd.DataFrame.from_dict(data)
# Out:
#              date rank          team current_year_total last_three last_game  \
# 0      2015-11-03    1  Golden State              119.0      121.7     119.0
# 1      2015-11-03    2     Okla City              118.2      120.3     105.0
# 2      2015-11-03    3    Sacramento              115.0      115.0     109.0
# 3      2015-11-03    4       Toronto              108.3      108.3     106.0
# 4      2015-11-03    5   LA Clippers              107.8      106.7     102.0
# ...           ...  ...           ...                ...        ...       ...
# 14875  2018-04-11   26       Chicago              103.1      101.7     105.0
# 14876  2018-04-11   27   San Antonio              102.8      108.7      98.0
# 14877  2018-04-11   28        Dallas              102.3      100.0      97.0
# 14878  2018-04-11   29       Memphis               99.0      105.7      94.0
# 14879  2018-04-11   30    Sacramento               98.9       91.0      85.0
#
#       home_score_avg away_score_avg
# 0              115.0          123.0
# 1              114.5          122.0
# 2              118.0          109.0
# 3              106.0          113.0
# 4              106.7          111.0
# ...              ...            ...
# 14875          103.7          102.5
# 14876          105.5          100.0
# 14877          103.8          100.8
# 14878          100.2           97.8
# 14879          100.8           97.0
#
# [14880 rows x 8 columns]

# %%
start_dt = date(2018, 10, 23)             
end_dt = date(2019,4,10)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)

# %%
pd.DataFrame.from_dict(data)
# Out:
#              date rank          team current_year_total last_three last_game  \
# 0      2015-11-03    1  Golden State              119.0      121.7     119.0
# 1      2015-11-03    2     Okla City              118.2      120.3     105.0
# 2      2015-11-03    3    Sacramento              115.0      115.0     109.0
# 3      2015-11-03    4       Toronto              108.3      108.3     106.0
# 4      2015-11-03    5   LA Clippers              107.8      106.7     102.0
# ...           ...  ...           ...                ...        ...       ...
# 19975  2019-04-10   26         Miami              105.9      113.3     122.0
# 19976  2019-04-10   27       Chicago              104.9       99.0      86.0
# 19977  2019-04-10   28      New York              104.8      101.7      96.0
# 19978  2019-04-10   29     Cleveland              104.5      100.3      97.0
# 19979  2019-04-10   30       Memphis              103.2      114.0      93.0
#
#       home_score_avg away_score_avg
# 0              115.0          123.0
# 1              114.5          122.0
# 2              118.0          109.0
# 3              106.0          113.0
# 4              106.7          111.0
# ...              ...            ...
# 19975          106.0          105.7
# 19976          103.6          106.2
# 19977          106.3          103.2
# 19978          105.2          103.8
# 19979          103.9          102.5
#
# [19980 rows x 8 columns]

# %%
start_dt = date(2019, 10, 29)             
end_dt = date(2020,3,11)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)

# %%
pd.DataFrame.from_dict(data)
# Out:
#              date rank          team current_year_total last_three last_game  \
# 0      2015-11-03    1  Golden State              119.0      121.7     119.0
# 1      2015-11-03    2     Okla City              118.2      120.3     105.0
# 2      2015-11-03    3    Sacramento              115.0      115.0     109.0
# 3      2015-11-03    4       Toronto              108.3      108.3     106.0
# 4      2015-11-03    5   LA Clippers              107.8      106.7     102.0
# ...           ...  ...           ...                ...        ...       ...
# 24025  2020-03-11   26       Chicago              106.8      105.7     108.0
# 24026  2020-03-11   27       Orlando              106.4      126.0     120.0
# 24027  2020-03-11   28  Golden State              106.3      112.7     107.0
# 24028  2020-03-11   29      New York              105.3      104.7     115.0
# 24029  2020-03-11   30     Charlotte              102.8      119.3     138.0
#
#       home_score_avg away_score_avg
# 0              115.0          123.0
# 1              114.5          122.0
# 2              118.0          109.0
# 3              106.0          113.0
# 4              106.7          111.0
# ...              ...            ...
# 24025          106.1          107.6
# 24026          104.9          107.7
# 24027          107.0          105.6
# 24028          105.4          105.3
# 24029          104.3          101.5
#
# [24030 rows x 8 columns]

# %%
start_dt = date(2020, 12, 30)             
end_dt = date(2021,3,4)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)

# %%
df = pd.DataFrame.from_dict(data)

# %%
df.to_csv("data/scoring_ranks_2015_2021.csv")

# %%
def daterange(date1, date2):
    for n in range(int ((date2 - date1).days)+1):
        yield date1 + timedelta(n)

# %%
dates = 1
def scrape_page(dates=dates):
    url = 'https://www.teamrankings.com/nba/stat/points-per-game?date=' + str(dates) 
    html = get(url)
    soup = Soup(html)
    
    trs = soup.find('tr')
    tr_pop = trs.pop(0)
    tr = trs[0]
    
    def parse_tr(tr):
        return {
            'date': str(dates),
            'rank': tr.find('td', {'class': 'rank text-center'}).text,
            'team': tr.find('td', {'class': 'text-left nowrap'}).text,
            'current_year_total': tr.find('td', {'class': 'text-right'})[0].text,
            'last_three': tr.find('td', {'class': 'text-right'})[1].text,
            'last_game': tr.find('td', {'class': 'text-right'})[2].text,
            'home_score_avg': tr.find('td', {'class': 'text-right'})[3].text,
            'away_score_avg': tr.find('td', {'class': 'text-right'})[4].text,
        }
    
    
    rankers = [parse_tr(tr) for tr in trs]
    return rankers

data = []
start_dt = date(2015, 11, 3)             
end_dt = date(2016,4,13)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)
    
start_dt = date(2016, 11, 1)             
end_dt = date(2017,4,12)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)
    
start_dt = date(2017, 10, 24)             
end_dt = date(2018,4,11)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)
    
start_dt = date(2018, 10, 23)             
end_dt = date(2019,4,10)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)
    
start_dt = date(2019, 10, 29)             
end_dt = date(2020,3,11)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)
    
start_dt = date(2020, 12, 30)             
end_dt = date(2021,3,4)
for i in daterange(start_dt, end_dt):
    data.extend(scrape_page(dates=i))
    time.sleep(.6)
    
df = pd.DataFrame.from_dict(data)

df.to_csv("data/test.csv")
## run time is about 26:30

# %%
df
# Out:
#              date rank          team current_year_total last_three last_game  \
# 0      2015-11-03    1  Golden State              119.0      121.7     119.0
# 1      2015-11-03    2     Okla City              118.2      120.3     105.0
# 2      2015-11-03    3    Sacramento              115.0      115.0     109.0
# 3      2015-11-03    4       Toronto              108.3      108.3     106.0
# 4      2015-11-03    5   LA Clippers              107.8      106.7     102.0
# ...           ...  ...           ...                ...        ...       ...
# 25975  2021-03-04   26         Miami              106.9      104.3      80.0
# 25976  2021-03-04   27     Okla City              105.9       97.3      78.0
# 25977  2021-03-04   28       Orlando              105.6      115.0     112.0
# 25978  2021-03-04   29      New York              104.6      104.0      93.0
# 25979  2021-03-04   30     Cleveland              104.6      108.0     111.0
#
#       home_score_avg away_score_avg
# 0              115.0          123.0
# 1              114.5          122.0
# 2              118.0          109.0
# 3              106.0          113.0
# 4              106.7          111.0
# ...              ...            ...
# 25975          106.9          106.9
# 25976          106.5          105.3
# 25977          106.3          104.8
# 25978          108.4          101.3
# 25979          108.1          100.7
#
# [25980 rows x 8 columns]
